# %%
# %matplotlib inline

import matplotlib.pyplot as plt 
import numpy as np
from dataclasses import dataclass
from tqdm import tqdm
import jax
import jax.numpy as jnp
from jax import grad, jit, vmap
from utils import *

# %%
#setups

config = configs()
config.init = 0.0
config.iter_num = 1000
config.sample_num = 500
config.lr_large = 0.62
config.lr_small = 0.01
config.rho = 1.0

print(config)
# Out:
# configs(init=0.0, iter_num=1000, sample_num=500, lr_large=0.62, lr_small=0.01, rho=1.0)

# %%
#plot smoothed objectfunction

x = np.linspace(-5, 5, 1000)
eta = 0.01
y = smoothed_obj(x, eta)

fig, ax = plt.subplots() 
ax.plot(x, y)
plt.title('Step size = 0.01')
fig.show()

obj = object_function
# Out:
# /var/folders/42/_8jtb5594rddnjmwctnf_xzm0000gn/T/ipykernel_16097/3107705400.py:17: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
sgd_l = optimize(config, 'SGD_large', obj)
sgd_s = optimize(config, 'SGD_small', obj)

ave_sgd_l = optimize(config, 'Ave_SGD_large', obj)
ave_sgd_s = optimize(config, 'Ave_SGD_small', obj)

noisy_sgd_l = optimize(config, 'Noisy_SGD_large', obj)
noisy_sgd_s = optimize(config, 'Noisy_SGD_small', obj)
# Out:
# 100%|█████████████████████████████████████| 500/500 [20:18:12<00:00, 146.18s/it]
# complete :  SGD_large
# 100%|███████████████████████████████████████| 500/500 [6:22:07<00:00, 45.86s/it]
# complete :  SGD_small
# 100%|██████████████████████████████████████| 500/500 [11:07:04<00:00, 80.05s/it]
# complete :  Ave_SGD_large
# 100%|███████████████████████████████████████| 500/500 [1:12:30<00:00,  8.70s/it]
# complete :  Ave_SGD_small
# 100%|█████████████████████████████████████████| 500/500 [53:07<00:00,  6.38s/it]
# complete :  Noisy_SGD_large
# 100%|█████████████████████████████████████████| 500/500 [44:35<00:00,  5.35s/it]
# complete :  Noisy_SGD_small

# %%
x = np.linspace(-5, 5, 1000)
y = object_function(x)

fig, ax = plt.subplots() 
plt.hist(sgd_s, bins=50, color=(0.7,0.7,0.7))
ax.scatter(sgd_l, object_function(sgd_l), color='b', label='large step size')
ax.scatter(sgd_s, object_function(sgd_s), color='r', label='small step size')
ax.plot(x, y)
plt.title('SGD')
plt.xlim(-5.5,5.5)
plt.ylim(0,30)
fig.legend()
fig.show()

#print(sgd_l, object_function(sgd_l))
#print(sgd_s, object_function(sgd_s))
# Out:
# /var/folders/42/_8jtb5594rddnjmwctnf_xzm0000gn/T/ipykernel_16097/92293439.py:13: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
x = np.linspace(-5, 5, 1000)
y = object_function(x)

fig, ax = plt.subplots() 
plt.hist(ave_sgd_l, bins=50, color=(0.7,0.7,0.7))
ax.scatter(ave_sgd_s, object_function(ave_sgd_s), color='r', label='small step size')
ax.scatter(ave_sgd_l, object_function(ave_sgd_l), color='b', label='large step size')
ax.plot(x, y)
plt.title('Averaged SGD')
fig.legend()
plt.xlim(-5.5,5.5)
plt.ylim(0,30)
fig.show()
#print(ave_sgd_l, object_function(ave_sgd_l))
#print(ave_sgd_s, object_function(ave_sgd_s))
# Out:
# /var/folders/42/_8jtb5594rddnjmwctnf_xzm0000gn/T/ipykernel_16097/4216226781.py:13: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
x = np.linspace(-5, 5, 1000)
y = object_function(x)

fig, ax = plt.subplots() 
plt.hist(noisy_sgd_s, bins=50, color=(0.7,0.7,0.7))
ax.scatter(noisy_sgd_l, object_function(noisy_sgd_l), color='b', label='large step size')
ax.scatter(noisy_sgd_s, object_function(noisy_sgd_s), color='r', label='small step size')
ax.plot(x, y)
fig.legend()
plt.title('Noisy SGD')
plt.xlim(-5.5,5.5)
plt.ylim(0,30)
fig.show()
#print(noisy_sgd_l, object_function(noisy_sgd_l))
#print(noisy_sgd_s, object_function(noisy_sgd_s))
# Out:
# /var/folders/42/_8jtb5594rddnjmwctnf_xzm0000gn/T/ipykernel_16097/905760272.py:13: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()
